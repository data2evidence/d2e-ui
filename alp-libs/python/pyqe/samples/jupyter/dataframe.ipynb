# %% [markdown]
# ## PyQE Download Dataframe Query Demo
#
# 1) Setup the imports

# %%
# Path has to be set before importing pyqe
import sys, os
sys.path.append(os.path.join(sys.path[0],'..', '..'))

import json
from pyqe import *

# %% [markdown]
# 2) Define authenticated query

# %%
query = Query('All_Patients_Dataframe_Query')
query.set_study('703c5d8a-a1d9-4d42-a314-5b9aad513390')

### NOTE: only one filter card type can be added for dataframe download
# Add Patient
query.add_filters([Person.Patient()])
# Add Interaction (OMOP)
query.add_filters([Interactions.ConditionOccurrence('condition')])
# Out:
# 23-Nov-2023 15:38:55 - INFO - Username is: admin
# 23-Nov-2023 15:38:55 - INFO - Authenticating with CFUAA..
# 23-Nov-2023 15:38:57 - INFO - Authentication successful

# %% [markdown]
# 3) Generate download cohort request

# %%
request = query.get_dataframe_cohort()
# Print request
# print(f'\nRequest: {json.dumps(request)}')

# %% [markdown]
# 4) Download dataframe with request

# %%
patient_dataframe = Result().download_dataframe(request, "patient.csv", limit = 50)
print(f'\nPatient dataframe: \n{patient_dataframe}')
# Out:
# Patient dataframe:
#        0  age  county               ethnicity  gender  \
# 0    999   85   23750  Not Hispanic or Latino  FEMALE
# 1   1011   96   42250  Not Hispanic or Latino    MALE
# 2   1001   82   32190  Not Hispanic or Latino    MALE
# 3    963   85   45431  Not Hispanic or Latino    MALE
# 4   1000  105   45720  Not Hispanic or Latino  FEMALE
# 5    968   99   11660  Not Hispanic or Latino  FEMALE
# 6    971   81   31150  Not Hispanic or Latino  FEMALE
# 7    984   91   37570  Not Hispanic or Latino  FEMALE
# 8   1012   70   49430  Not Hispanic or Latino    MALE
# 9   1014   85   10280  Not Hispanic or Latino    MALE
# 10   975   85    5380  Not Hispanic or Latino    MALE
# 11   973   84   26140  Not Hispanic or Latino    MALE
# 12   982   71   44270  Not Hispanic or Latino  FEMALE
# 13   997   75   15190  Not Hispanic or Latino  FEMALE
# 14   979   98   31000  Not Hispanic or Latino  FEMALE
# 15  1010   82   10650  Not Hispanic or Latino    MALE
# 16  1004   85   44780  Not Hispanic or Latino  FEMALE
# 17   964   91    5460  Not Hispanic or Latino  FEMALE
# 18   988   87   38070  Not Hispanic or Latino    MALE
# 19  1013   44   36170  Not Hispanic or Latino  FEMALE
# 20  1007   86   34250  Not Hispanic or Latino    MALE
# 21  1021   80    6150  Not Hispanic or Latino  FEMALE
# 22  1003   81   25330  Not Hispanic or Latino    MALE
# 23  1015   87   23810  Not Hispanic or Latino    MALE
# 24   981   80   45885  Not Hispanic or Latino  FEMALE
# 25   967   92    5090  Not Hispanic or Latino  FEMALE
# 26   985   95   37060  Not Hispanic or Latino    MALE
# 27   991   86   35370  Not Hispanic or Latino    MALE
# 28  1018  100   52390  Not Hispanic or Latino  FEMALE
# 29  1017   91   22040  Not Hispanic or Latino  FEMALE
# 30   996   77   20110  Not Hispanic or Latino    MALE
# 31  1005   95   24680  Not Hispanic or Latino  FEMALE
# 32   965   89   44170  Not Hispanic or Latino    MALE
# 33   990  100   45390  Not Hispanic or Latino    MALE
# 34   966   86   10120  Not Hispanic or Latino  FEMALE
# 35   970   50   10570  Not Hispanic or Latino  FEMALE
# 36   983  107   33800  Not Hispanic or Latino    MALE
# 37   976   80   31200  Not Hispanic or Latino  FEMALE
# 38   992   92   31200  Not Hispanic or Latino    MALE
# 39   969  101   32230  Not Hispanic or Latino  FEMALE
# 40   972   98   30040  Not Hispanic or Latino    MALE
# 41   998  102    5200  Not Hispanic or Latino  FEMALE
# 42   993   81   11090  Not Hispanic or Latino  FEMALE
# 43  1002   91    5400  Not Hispanic or Latino    MALE
# 44   977  101   22090  Not Hispanic or Latino  FEMALE
# 45  1016   87    5460  Not Hispanic or Latino  FEMALE
# 46  1020   84    5400  Not Hispanic or Latino  FEMALE
# 47   989   98   22000  Not Hispanic or Latino  FEMALE
# 48  1008   85   52150  Not Hispanic or Latino    MALE
# 49   987   80    3060  Not Hispanic or Latino    MALE
#
#                          race state dateofbirth dateofdeath  \
# 0                       White    MI  1938-03-01         NaN
# 1                       White    SC  1927-12-01         NaN
# 2                       White    NM  1941-04-01         NaN
# 3                       White    TX  1938-04-01         NaN
# 4                       White    TX  1918-04-01         NaN
# 5                       White    GA  1924-05-01  2010-09-01
# 6                       White    NJ  1942-12-01         NaN
# 7                       White    OK  1932-06-01         NaN
# 8   Black or African American    VA  1953-06-01         NaN
# 9                       White    FL  1938-07-01         NaN
# 10        No matching concept    CA  1938-10-01         NaN
# 11                      White    MO  1939-05-01         NaN
# 12                      White    TN  1952-10-01         NaN
# 13                      White    IN  1948-07-01         NaN
# 14                      White    NJ  1925-05-01         NaN
# 15  Black or African American    FL  1941-09-01         NaN
# 16                      White    TN  1938-04-01         NaN
# 17                      White    CA  1932-08-01         NaN
# 18                      White    OR  1936-04-01  2010-07-01
# 19                      White    OH  1979-10-01         NaN
# 20  Black or African American    NC  1937-05-01         NaN
# 21                      White    CO  1943-01-01         NaN
# 22  Black or African American    MS  1942-10-01         NaN
# 23                      White    MI  1936-04-01         NaN
# 24                      White    TX  1943-10-01         NaN
# 25                      White    CA  1931-12-01         NaN
# 26                      White    OK  1928-10-01         NaN
# 27                      White    ND  1937-10-01         NaN
# 28                      White    WI  1923-07-01         NaN
# 29                      White    MA  1932-02-01         NaN
# 30                      White    ME  1946-05-01         NaN
# 31                      White    MN  1928-11-01         NaN
# 32  Black or African American    TN  1934-09-01         NaN
# 33                      White    TX  1923-06-01         NaN
# 34                      White    FL  1937-08-01         NaN
# 35                      White    FL  1973-02-01         NaN
# 36                      White    NY  1916-04-01         NaN
# 37  Black or African American    NJ  1943-05-01         NaN
# 38                      White    NJ  1931-06-01         NaN
# 39                      White    NM  1922-03-01         NaN
# 40                      White    NH  1925-07-01         NaN
# 41                      White    CA  1921-03-01         NaN
# 42  Black or African American    GA  1942-09-01         NaN
# 43                      White    CA  1932-01-01         NaN
# 44                      White    MA  1922-01-01         NaN
# 45                      White    CA  1936-06-01         NaN
# 46                      White    CA  1939-08-01         NaN
# 47                      White    MA  1925-09-01         NaN
# 48                      White    WI  1938-04-01         NaN
# 49                      White    AZ  1943-03-01         NaN
#
#    ethnicityconceptcode  ... genderconceptcode genderconceptid  groupid  \
# 0          Not Hispanic  ...                 F            8532      NaN
# 1          Not Hispanic  ...                 M            8507      NaN
# 2          Not Hispanic  ...                 M            8507      NaN
# 3          Not Hispanic  ...                 M            8507      NaN
# 4          Not Hispanic  ...                 F            8532      NaN
# 5          Not Hispanic  ...                 F            8532      NaN
# 6          Not Hispanic  ...                 F            8532      NaN
# 7          Not Hispanic  ...                 F            8532      NaN
# 8          Not Hispanic  ...                 M            8507      NaN
# 9          Not Hispanic  ...                 M            8507      NaN
# 10         Not Hispanic  ...                 M            8507      NaN
# 11         Not Hispanic  ...                 M            8507      NaN
# 12         Not Hispanic  ...                 F            8532      NaN
# 13         Not Hispanic  ...                 F            8532      NaN
# 14         Not Hispanic  ...                 F            8532      NaN
# 15         Not Hispanic  ...                 M            8507      NaN
# 16         Not Hispanic  ...                 F            8532      NaN
# 17         Not Hispanic  ...                 F            8532      NaN
# 18         Not Hispanic  ...                 M            8507      NaN
# 19         Not Hispanic  ...                 F            8532      NaN
# 20         Not Hispanic  ...                 M            8507      NaN
# 21         Not Hispanic  ...                 F            8532      NaN
# 22         Not Hispanic  ...                 M            8507      NaN
# 23         Not Hispanic  ...                 M            8507      NaN
# 24         Not Hispanic  ...                 F            8532      NaN
# 25         Not Hispanic  ...                 F            8532      NaN
# 26         Not Hispanic  ...                 M            8507      NaN
# 27         Not Hispanic  ...                 M            8507      NaN
# 28         Not Hispanic  ...                 F            8532      NaN
# 29         Not Hispanic  ...                 F            8532      NaN
# 30         Not Hispanic  ...                 M            8507      NaN
# 31         Not Hispanic  ...                 F            8532      NaN
# 32         Not Hispanic  ...                 M            8507      NaN
# 33         Not Hispanic  ...                 M            8507      NaN
# 34         Not Hispanic  ...                 F            8532      NaN
# 35         Not Hispanic  ...                 F            8532      NaN
# 36         Not Hispanic  ...                 M            8507      NaN
# 37         Not Hispanic  ...                 F            8532      NaN
# 38         Not Hispanic  ...                 M            8507      NaN
# 39         Not Hispanic  ...                 F            8532      NaN
# 40         Not Hispanic  ...                 M            8507      NaN
# 41         Not Hispanic  ...                 F            8532      NaN
# 42         Not Hispanic  ...                 F            8532      NaN
# 43         Not Hispanic  ...                 M            8507      NaN
# 44         Not Hispanic  ...                 F            8532      NaN
# 45         Not Hispanic  ...                 F            8532      NaN
# 46         Not Hispanic  ...                 F            8532      NaN
# 47         Not Hispanic  ...                 F            8532      NaN
# 48         Not Hispanic  ...                 M            8507      NaN
# 49         Not Hispanic  ...                 M            8507      NaN
#
#        lastauthoreddate monthofbirth   pid      raceconceptcode raceconceptid  \
# 0                   NaN            3   999                    5          8527
# 1                   NaN           12  1011                    5          8527
# 2                   NaN            4  1001                    5          8527
# 3                   NaN            4   963                    5          8527
# 4                   NaN            4  1000                    5          8527
# 5                   NaN            5   968                    5          8527
# 6                   NaN           12   971                    5          8527
# 7   2010-12-17T00:00:00            6   984                    5          8527
# 8                   NaN            6  1012                    3          8516
# 9                   NaN            7  1014                    5          8527
# 10                  NaN           10   975  No matching concept             0
# 11                  NaN            5   973                    5          8527
# 12                  NaN           10   982                    5          8527
# 13                  NaN            7   997                    5          8527
# 14  2009-08-20T00:00:00            5   979                    5          8527
# 15  2021-10-20T00:00:00            9  1010                    3          8516
# 16  2010-06-07T00:00:00            4  1004                    5          8527
# 17  2010-12-07T00:00:00            8   964                    5          8527
# 18                  NaN            4   988                    5          8527
# 19                  NaN           10  1013                    5          8527
# 20                  NaN            5  1007                    3          8516
# 21                  NaN            1  1021                    5          8527
# 22  2010-08-18T00:00:00           10  1003                    3          8516
# 23                  NaN            4  1015                    5          8527
# 24  2021-09-08T00:00:00           10   981                    5          8527
# 25                  NaN           12   967                    5          8527
# 26  2010-04-16T00:00:00           10   985                    5          8527
# 27  2010-06-11T00:00:00           10   991                    5          8527
# 28                  NaN            7  1018                    5          8527
# 29                  NaN            2  1017                    5          8527
# 30  2010-08-21T00:00:00            5   996                    5          8527
# 31                  NaN           11  1005                    5          8527
# 32                  NaN            9   965                    3          8516
# 33  2021-09-08T00:00:00            6   990                    5          8527
# 34  2010-11-20T00:00:00            8   966                    5          8527
# 35  2010-10-27T00:00:00            2   970                    5          8527
# 36  2010-06-30T00:00:00            4   983                    5          8527
# 37                  NaN            5   976                    3          8516
# 38  2021-09-08T00:00:00            6   992                    5          8527
# 39                  NaN            3   969                    5          8527
# 40  2010-10-25T00:00:00            7   972                    5          8527
# 41  2010-06-19T00:00:00            3   998                    5          8527
# 42  2009-06-06T00:00:00            9   993                    3          8516
# 43                  NaN            1  1002                    5          8527
# 44                  NaN            1   977                    5          8527
# 45                  NaN            6  1016                    5          8527
# 46                  NaN            8  1020                    5          8527
# 47  2010-05-01T00:00:00            9   989                    5          8527
# 48                  NaN            4  1008                    5          8527
# 49                  NaN            3   987                    5          8527
#
#        status yearofbirth
# 0         NaN        1938
# 1         NaN        1927
# 2         NaN        1941
# 3         NaN        1938
# 4         NaN        1918
# 5         NaN        1924
# 6         NaN        1942
# 7   withdrawn        1932
# 8         NaN        1953
# 9         NaN        1938
# 10        NaN        1938
# 11        NaN        1939
# 12        NaN        1952
# 13        NaN        1948
# 14   enrolled        1925
# 15   enrolled        1941
# 16   enrolled        1938
# 17  withdrawn        1932
# 18        NaN        1936
# 19        NaN        1979
# 20        NaN        1937
# 21        NaN        1943
# 22  withdrawn        1942
# 23        NaN        1936
# 24   enrolled        1943
# 25        NaN        1931
# 26  withdrawn        1928
# 27   enrolled        1937
# 28        NaN        1923
# 29        NaN        1932
# 30  withdrawn        1946
# 31        NaN        1928
# 32        NaN        1934
# 33   enrolled        1923
# 34  withdrawn        1937
# 35  withdrawn        1973
# 36  withdrawn        1916
# 37        NaN        1943
# 38   enrolled        1931
# 39        NaN        1922
# 40  withdrawn        1925
# 41  withdrawn        1921
# 42  withdrawn        1942
# 43        NaN        1932
# 44        NaN        1922
# 45        NaN        1936
# 46        NaN        1939
# 47   enrolled        1925
# 48        NaN        1938
# 49        NaN        1943
#
# [50 rows x 21 columns]

# %% [markdown]
# 5. Download a portion of dataframe with request

# %%
patient_dataframe_subset = Result().download_dataframe(request, "patient.csv", limit=50, offset=15)
print(f'\nPatient dataframe: \n{patient_dataframe_subset}')
# Out:
# Patient dataframe:
#        0  age  county               ethnicity  gender  \
# 0    999   85   23750  Not Hispanic or Latino  FEMALE
# 1   1011   96   42250  Not Hispanic or Latino    MALE
# 2   1001   82   32190  Not Hispanic or Latino    MALE
# 3   1000  105   45720  Not Hispanic or Latino  FEMALE
# 4   1032   81   21030  Not Hispanic or Latino    MALE
# 5   1031  104    5530  Not Hispanic or Latino  FEMALE
# 6    984   91   37570  Not Hispanic or Latino  FEMALE
# 7   1012   70   49430  Not Hispanic or Latino    MALE
# 8   1033  104    5030  Not Hispanic or Latino  FEMALE
# 9   1029   88    2110  Not Hispanic or Latino  FEMALE
# 10  1014   85   10280  Not Hispanic or Latino    MALE
# 11  1025   93   21040  Not Hispanic or Latino  FEMALE
# 12   982   71   44270  Not Hispanic or Latino  FEMALE
# 13   997   75   15190  Not Hispanic or Latino  FEMALE
# 14  1010   82   10650  Not Hispanic or Latino    MALE
# 15  1004   85   44780  Not Hispanic or Latino  FEMALE
# 16   988   87   38070  Not Hispanic or Latino    MALE
# 17  1013   44   36170  Not Hispanic or Latino  FEMALE
# 18  1027   84   15350  Not Hispanic or Latino  FEMALE
# 19  1007   86   34250  Not Hispanic or Latino    MALE
# 20  1021   80    6150  Not Hispanic or Latino  FEMALE
# 21  1003   81   25330  Not Hispanic or Latino    MALE
# 22  1015   87   23810  Not Hispanic or Latino    MALE
# 23   981   80   45885  Not Hispanic or Latino  FEMALE
# 24   985   95   37060  Not Hispanic or Latino    MALE
# 25   991   86   35370  Not Hispanic or Latino    MALE
# 26  1037   85   25170  Not Hispanic or Latino  FEMALE
# 27   996   77   20110  Not Hispanic or Latino    MALE
# 28  1018  100   52390  Not Hispanic or Latino  FEMALE
# 29  1005   95   24680  Not Hispanic or Latino  FEMALE
# 30  1017   91   22040  Not Hispanic or Latino  FEMALE
# 31  1034   94   45610  Not Hispanic or Latino  FEMALE
# 32   990  100   45390  Not Hispanic or Latino    MALE
# 33  1035   72   15310  Not Hispanic or Latino    MALE
# 34  1028   82    5530  Not Hispanic or Latino    MALE
# 35   983  107   33800  Not Hispanic or Latino    MALE
# 36  1038  109   26470  Not Hispanic or Latino  FEMALE
# 37   992   92   31200  Not Hispanic or Latino    MALE
# 38   998  102    5200  Not Hispanic or Latino  FEMALE
# 39   993   81   11090  Not Hispanic or Latino  FEMALE
# 40  1002   91    5400  Not Hispanic or Latino    MALE
# 41  1030   61   51090  Not Hispanic or Latino  FEMALE
# 42  1016   87    5460  Not Hispanic or Latino  FEMALE
# 43  1020   84    5400  Not Hispanic or Latino  FEMALE
# 44   989   98   22000  Not Hispanic or Latino  FEMALE
# 45  1008   85   52150  Not Hispanic or Latino    MALE
# 46  1022  101   42400  Not Hispanic or Latino  FEMALE
# 47  1026   93   39540  Not Hispanic or Latino  FEMALE
# 48   987   80    3060  Not Hispanic or Latino    MALE
# 49  1024   83   23000  Not Hispanic or Latino  FEMALE
#
#                          race state dateofbirth dateofdeath  \
# 0                       White    MI  1938-03-01         NaN
# 1                       White    SC  1927-12-01         NaN
# 2                       White    NM  1941-04-01         NaN
# 3                       White    TX  1918-04-01         NaN
# 4                       White    MD  1942-10-01         NaN
# 5                       White    CA  1919-02-01         NaN
# 6                       White    OK  1932-06-01         NaN
# 7   Black or African American    VA  1953-06-01         NaN
# 8                       White    CA  1919-05-01         NaN
# 9   Black or African American    AK  1935-09-01         NaN
# 10                      White    FL  1938-07-01         NaN
# 11                      White    MD  1930-05-01         NaN
# 12                      White    TN  1952-10-01         NaN
# 13                      White    IN  1948-07-01         NaN
# 14  Black or African American    FL  1941-09-01         NaN
# 15                      White    TN  1938-04-01         NaN
# 16                      White    OR  1936-04-01  2010-07-01
# 17                      White    OH  1979-10-01         NaN
# 18                      White    IN  1939-12-01         NaN
# 19  Black or African American    NC  1937-05-01         NaN
# 20                      White    CO  1943-01-01         NaN
# 21  Black or African American    MS  1942-10-01         NaN
# 22                      White    MI  1936-04-01         NaN
# 23                      White    TX  1943-10-01         NaN
# 24                      White    OK  1928-10-01         NaN
# 25                      White    ND  1937-10-01         NaN
# 26  Black or African American    MS  1938-08-01         NaN
# 27                      White    ME  1946-05-01         NaN
# 28                      White    WI  1923-07-01         NaN
# 29                      White    MN  1928-11-01         NaN
# 30                      White    MA  1932-02-01         NaN
# 31                      White    TX  1929-05-01         NaN
# 32                      White    TX  1923-06-01         NaN
# 33                      White    IN  1951-01-01  2009-07-01
# 34        No matching concept    CA  1941-04-01         NaN
# 35                      White    NY  1916-04-01         NaN
# 36                      White    MO  1914-12-01         NaN
# 37                      White    NJ  1931-06-01         NaN
# 38                      White    CA  1921-03-01         NaN
# 39  Black or African American    GA  1942-09-01         NaN
# 40                      White    CA  1932-01-01         NaN
# 41                      White    WV  1962-08-01         NaN
# 42                      White    CA  1936-06-01         NaN
# 43                      White    CA  1939-08-01         NaN
# 44                      White    MA  1925-09-01         NaN
# 45                      White    WI  1938-04-01         NaN
# 46                      White    SC  1922-03-01         NaN
# 47  Black or African American    PA  1930-04-01         NaN
# 48                      White    AZ  1943-03-01         NaN
# 49                      White    MI  1940-10-01         NaN
#
#    ethnicityconceptcode  ... genderconceptcode genderconceptid  groupid  \
# 0          Not Hispanic  ...                 F            8532      NaN
# 1          Not Hispanic  ...                 M            8507      NaN
# 2          Not Hispanic  ...                 M            8507      NaN
# 3          Not Hispanic  ...                 F            8532      NaN
# 4          Not Hispanic  ...                 M            8507      NaN
# 5          Not Hispanic  ...                 F            8532      NaN
# 6          Not Hispanic  ...                 F            8532      NaN
# 7          Not Hispanic  ...                 M            8507      NaN
# 8          Not Hispanic  ...                 F            8532      NaN
# 9          Not Hispanic  ...                 F            8532      NaN
# 10         Not Hispanic  ...                 M            8507      NaN
# 11         Not Hispanic  ...                 F            8532      NaN
# 12         Not Hispanic  ...                 F            8532      NaN
# 13         Not Hispanic  ...                 F            8532      NaN
# 14         Not Hispanic  ...                 M            8507      NaN
# 15         Not Hispanic  ...                 F            8532      NaN
# 16         Not Hispanic  ...                 M            8507      NaN
# 17         Not Hispanic  ...                 F            8532      NaN
# 18         Not Hispanic  ...                 F            8532      NaN
# 19         Not Hispanic  ...                 M            8507      NaN
# 20         Not Hispanic  ...                 F            8532      NaN
# 21         Not Hispanic  ...                 M            8507      NaN
# 22         Not Hispanic  ...                 M            8507      NaN
# 23         Not Hispanic  ...                 F            8532      NaN
# 24         Not Hispanic  ...                 M            8507      NaN
# 25         Not Hispanic  ...                 M            8507      NaN
# 26         Not Hispanic  ...                 F            8532      NaN
# 27         Not Hispanic  ...                 M            8507      NaN
# 28         Not Hispanic  ...                 F            8532      NaN
# 29         Not Hispanic  ...                 F            8532      NaN
# 30         Not Hispanic  ...                 F            8532      NaN
# 31         Not Hispanic  ...                 F            8532      NaN
# 32         Not Hispanic  ...                 M            8507      NaN
# 33         Not Hispanic  ...                 M            8507      NaN
# 34         Not Hispanic  ...                 M            8507      NaN
# 35         Not Hispanic  ...                 M            8507      NaN
# 36         Not Hispanic  ...                 F            8532      NaN
# 37         Not Hispanic  ...                 M            8507      NaN
# 38         Not Hispanic  ...                 F            8532      NaN
# 39         Not Hispanic  ...                 F            8532      NaN
# 40         Not Hispanic  ...                 M            8507      NaN
# 41         Not Hispanic  ...                 F            8532      NaN
# 42         Not Hispanic  ...                 F            8532      NaN
# 43         Not Hispanic  ...                 F            8532      NaN
# 44         Not Hispanic  ...                 F            8532      NaN
# 45         Not Hispanic  ...                 M            8507      NaN
# 46         Not Hispanic  ...                 F            8532      NaN
# 47         Not Hispanic  ...                 F            8532      NaN
# 48         Not Hispanic  ...                 M            8507      NaN
# 49         Not Hispanic  ...                 F            8532      NaN
#
#        lastauthoreddate monthofbirth   pid      raceconceptcode raceconceptid  \
# 0                   NaN            3   999                    5          8527
# 1                   NaN           12  1011                    5          8527
# 2                   NaN            4  1001                    5          8527
# 3                   NaN            4  1000                    5          8527
# 4                   NaN           10  1032                    5          8527
# 5                   NaN            2  1031                    5          8527
# 6   2010-12-17T00:00:00            6   984                    5          8527
# 7                   NaN            6  1012                    3          8516
# 8                   NaN            5  1033                    5          8527
# 9                   NaN            9  1029                    3          8516
# 10                  NaN            7  1014                    5          8527
# 11                  NaN            5  1025                    5          8527
# 12                  NaN           10   982                    5          8527
# 13                  NaN            7   997                    5          8527
# 14  2021-10-20T00:00:00            9  1010                    3          8516
# 15  2010-06-07T00:00:00            4  1004                    5          8527
# 16                  NaN            4   988                    5          8527
# 17                  NaN           10  1013                    5          8527
# 18                  NaN           12  1027                    5          8527
# 19                  NaN            5  1007                    3          8516
# 20                  NaN            1  1021                    5          8527
# 21  2010-08-18T00:00:00           10  1003                    3          8516
# 22                  NaN            4  1015                    5          8527
# 23  2021-09-08T00:00:00           10   981                    5          8527
# 24  2010-04-16T00:00:00           10   985                    5          8527
# 25  2010-06-11T00:00:00           10   991                    5          8527
# 26  2021-09-22T00:00:00            8  1037                    3          8516
# 27  2010-08-21T00:00:00            5   996                    5          8527
# 28                  NaN            7  1018                    5          8527
# 29                  NaN           11  1005                    5          8527
# 30                  NaN            2  1017                    5          8527
# 31  2010-12-22T00:00:00            5  1034                    5          8527
# 32  2021-09-08T00:00:00            6   990                    5          8527
# 33                  NaN            1  1035                    5          8527
# 34                  NaN            4  1028  No matching concept             0
# 35  2010-06-30T00:00:00            4   983                    5          8527
# 36  2010-11-26T00:00:00           12  1038                    5          8527
# 37  2021-09-08T00:00:00            6   992                    5          8527
# 38  2010-06-19T00:00:00            3   998                    5          8527
# 39  2009-06-06T00:00:00            9   993                    3          8516
# 40                  NaN            1  1002                    5          8527
# 41  2010-03-26T00:00:00            8  1030                    5          8527
# 42                  NaN            6  1016                    5          8527
# 43                  NaN            8  1020                    5          8527
# 44  2010-05-01T00:00:00            9   989                    5          8527
# 45                  NaN            4  1008                    5          8527
# 46                  NaN            3  1022                    5          8527
# 47                  NaN            4  1026                    3          8516
# 48                  NaN            3   987                    5          8527
# 49                  NaN           10  1024                    5          8527
#
#        status yearofbirth
# 0         NaN        1938
# 1         NaN        1927
# 2         NaN        1941
# 3         NaN        1918
# 4         NaN        1942
# 5         NaN        1919
# 6   withdrawn        1932
# 7         NaN        1953
# 8         NaN        1919
# 9         NaN        1935
# 10        NaN        1938
# 11        NaN        1930
# 12        NaN        1952
# 13        NaN        1948
# 14   enrolled        1941
# 15   enrolled        1938
# 16        NaN        1936
# 17        NaN        1979
# 18        NaN        1939
# 19        NaN        1937
# 20        NaN        1943
# 21  withdrawn        1942
# 22        NaN        1936
# 23   enrolled        1943
# 24  withdrawn        1928
# 25   enrolled        1937
# 26   enrolled        1938
# 27  withdrawn        1946
# 28        NaN        1923
# 29        NaN        1928
# 30        NaN        1932
# 31  withdrawn        1929
# 32   enrolled        1923
# 33        NaN        1951
# 34        NaN        1941
# 35  withdrawn        1916
# 36   enrolled        1914
# 37   enrolled        1931
# 38  withdrawn        1921
# 39  withdrawn        1942
# 40        NaN        1932
# 41  withdrawn        1962
# 42        NaN        1936
# 43        NaN        1939
# 44   enrolled        1925
# 45        NaN        1938
# 46        NaN        1922
# 47        NaN        1930
# 48        NaN        1943
# 49        NaN        1940
#
# [50 rows x 21 columns]

# %% [markdown]
# 6) Define authenticated query with female filter

# %%
female_query = Query('Female_Patients_Dataframe_Query')
female_query.set_study('703c5d8a-a1d9-4d42-a314-5b9aad513390')
female_patient = Person.Patient()
female_constraint = Constraint().add(Expression(ComparisonOperator.EQUAL, 'Female'))
female_patient.add_gender([female_constraint])

female_query.add_filters([female_patient])

# %% [markdown]
# 7) Generate download cohort request with specific column config paths for one filter card type

# %%
specific_columns_request = female_query.get_dataframe_cohort(['patient.attributes.pid', 'patient.attributes.Age', 'patient.attributes.Gender'])
# Print request
# print(f'\nRequest: {json.dumps(specific_columns_request)}')

# %% [markdown]
# 8) Download dataframe with request

# %%
female_patient_dataframe = Result().download_dataframe(specific_columns_request, "female_patient.csv")
print(f'\nFemale patient dataframe: \n{female_patient_dataframe}')
# Out:
# Female patient dataframe:
#      age  gender  pid
# 0     91  FEMALE  964
# 1     86  FEMALE  966
# 2     92  FEMALE  967
# 3     99  FEMALE  968
# 4    101  FEMALE  969
# ..   ...     ...  ...
# 534   87  FEMALE  119
# 535  110  FEMALE  124
# 536   95  FEMALE  126
# 537   81  FEMALE  127
# 538   83  FEMALE  129
#
# [539 rows x 3 columns]

# %% [markdown]
# 9. Download portion of dataframe with request

# %%
female_patient_dataframe_subset = Result().download_dataframe(specific_columns_request, "female_patient.csv", limit = 100, offset = 10)
print(f'\nFemale patient dataframe: \n{female_patient_dataframe_subset}')
# Out:
# Female patient dataframe:
#     age  gender   pid
# 0    89  FEMALE  1094
# 1    89  FEMALE  1040
# 2    94  FEMALE  1084
# 3    91  FEMALE   984
# 4    90  FEMALE  1083
# ..  ...     ...   ...
# 95   96  FEMALE   844
# 96   93  FEMALE   689
# 97   83  FEMALE  1069
# 98  101  FEMALE  1022
# 99  104  FEMALE  1033
#
# [100 rows x 3 columns]
